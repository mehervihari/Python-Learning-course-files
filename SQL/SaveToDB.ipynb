# %%
import psycopg2 as pg2
import pandas as pd

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/Programming_languages_used_in_most_popular_websites')

# %%
data

# %%
df = data[0]

# %%
df
# Out:
#          Websites  Popularity(unique visitors per month)[1]  \
# 0       Google[2]                                1600000000
# 1        Facebook                                1100000000
# 2         YouTube                                1100000000
# 3           Yahoo                                 750000000
# 4          Amazon                                 500000000
# 5       Wikipedia                                 475000000
# 6         Twitter                                 290000000
# 7            Bing                                 285000000
# 8            eBay                                 285000000
# 9             MSN                                 280000000
# 10       LinkedIn                                 260000000
# 11      Pinterest                                 250000000
# 12  WordPress.com                                 240000000
#
#     Front-end(Client-side)                              Back-end(Server-side)  \
# ...

# %%
df = df.rename(columns = {'Popularity(unique visitors per month)[1]' : 'Popularity',
                         'Front-end(Client-side)' : 'Frontend',
                         'Back-end(Server-side)' : 'Backend'})

# %%
conn = pg2.connect(database = 'Airlinesone', user = 'postgres', password = 654321, port = 5432)

# %%
# saving db to pgadmin4
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://postgres:654321@localhost:5432/programming')

df.to_sql('popular_languages', engine, if_exists='append', index = False)
